# %%
import pandas as pd
import numpy as np
train = pd.read_csv("fraudtrain.csv")
test = pd.read_csv("fraudtest.csv")

# %% [markdown]
# # Shape of the Data

# %%
print("Training:")
print(train.shape)
print("Testing:")
print(test.shape)
# Out:
# Training:
# (1296675, 23)
# Testing:
# (555719, 23)

# %% [markdown]
# # Head of The Training Data

# %%
print("Training:")
train.head()
# Out:
# Training:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %% [markdown]
# # Testing Data head

# %%
print("Testing:")
test.head()
# Out:
# Testing:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt

# Assuming train is your DataFrame and "is_fraud" is a column in it
y_train = train["is_fraud"]

# Calculate value counts
z = y_train.value_counts()

# Create a pie chart
fig, ax = plt.subplots()
ax.pie(z, labels=z.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'black'])

# Draw a circle to make it a donut chart
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig.gca().add_artist(centre_circle)

# Equal aspect ratio ensures that pie is drawn as a circle
ax.axis('equal')  
plt.tight_layout()

# Show the plot
plt.title('Fraudulent vs Non-Fraudulent Transactions\n')

plt.show()

# %%
# Assuming train is your DataFrame and "is_fraud" is a column in it
states = train["state"]
# Calculate value counts
z = states.value_counts()
colors = plt.cm.tab10(np.arange(len(z)))
plt.figure(figsize=(12, 8))
z.plot(kind="bar", color=colors)
plt.show()

# %% [markdown]
# # Encoding

# %%
mean_encoding_map = train.groupby("merchant")['is_fraud'].mean().to_dict()


train['merchant_Mean_Encoded'] = train['merchant'].map(mean_encoding_map)

# %%
mean_encoding_map = train.groupby("state")['is_fraud'].mean().to_dict()


train['state_Mean_Encoded'] = train['state'].map(mean_encoding_map)

# %%
mean_encoding_map = train.groupby("last")['is_fraud'].mean().to_dict()


train['last_Mean_Encoded'] = train['last'].map(mean_encoding_map)

# %%
mean_encoding_map = train.groupby("city_pop")['is_fraud'].mean().to_dict()

train['city_pop_Mean_Encoded'] = train['city_pop'].map(mean_encoding_map)

# %%
mean_encoding_map = train.groupby("cc_num")['is_fraud'].mean().to_dict()

train['cc_num_Mean_Encoded'] = train['cc_num'].map(mean_encoding_map)

# %%
mean_encoding_map = train.groupby("category")['is_fraud'].mean().to_dict()

train['category_Mean_Encoded'] = train['category'].map(mean_encoding_map)

# %%
mean_encoding_map = train.groupby("first")['is_fraud'].mean().to_dict()

train['first_Mean_Encoded'] = train['first'].map(mean_encoding_map)

# %%
mean_encoding_map = train.groupby("zip")['is_fraud'].mean().to_dict()

train['zip_Mean_Encoded'] = train['zip'].map(mean_encoding_map)

# %%
mean_encoding_map = train.groupby("lat")['is_fraud'].mean().to_dict()

train['lat_Mean_Encoded'] = train['lat'].map(mean_encoding_map)

# %%
mean_encoding_map = train.groupby("long")['is_fraud'].mean().to_dict()

train['long_Mean_Encoded'] = train['long'].map(mean_encoding_map)

# %%
mean_encoding_map = train.groupby("unix_time")['is_fraud'].mean().to_dict()

train['unix_time_Mean_Encoded'] = train['unix_time'].map(mean_encoding_map)

# %%
mean_encoding_map = train.groupby("merch_lat")['is_fraud'].mean().to_dict()

train['merch_lat_Mean_Encoded'] = train['merch_lat'].map(mean_encoding_map)

# %%
mean_encoding_map = train.groupby("merch_long")['is_fraud'].mean().to_dict()

train['merch_long_Mean_Encoded'] = train['merch_long'].map(mean_encoding_map)

# %%
col = ["merch_long","merch_lat","unix_time","long","city","lat",'zip','cc_num',"category",'first',"trans_date_trans_time", "trans_num","dob", "street","job","last","state","merchant","amt","last","city_pop"]
train.drop(columns=col)
# Out:
#          Unnamed: 0 gender  is_fraud  Job_Type_Mean_Encoded  \
# 0                 0      F         0               0.001693
# 1                 1      F         0               0.002157
# 2                 2      M         0               0.015656
# 3                 3      M         0               0.007905
# 4                 4      M         0               0.000000
# ...             ...    ...       ...                    ...
# 1296670     1296670      M         0               0.005338
# 1296671     1296671      M         0               0.015066
# 1296672     1296672      M         0               0.006103
# 1296673     1296673      M         0               0.003953
# 1296674     1296674      M         0               0.007120
#
#          merchant_Mean_Encoded  state_Mean_Encoded  last_Mean_Encoded  \
# 0                     0.014207            0.004923           0.000000
# 1                     0.010787            0.005073           0.002633
# ...

# %%
mean_encoding_map = train.groupby("city")['is_fraud'].mean().to_dict()

train['city_Mean_Encoded'] = train['city'].map(mean_encoding_map)

# %%
from sklearn.preprocessing import LabelEncoder
# Sample data

# Label Encoding
label_encoder = LabelEncoder()
train['gender_encoded'] = label_encoder.fit_transform(train['gender'])

mean_encoding_map = train.groupby("city")['is_fraud'].mean().to_dict()

train['city_Mean_Encoded'] = train['city'].map(mean_encoding_map)

# %%
col = ["merch_long","merch_lat","Job_Type_Mean_Encoded","gender","unix_time","long","city","lat",'zip','cc_num',"category",'first',"trans_date_trans_time", "trans_num","dob", "street","job","last","state","merchant","amt","last","city_pop"]
Train = train.drop(columns=col)
print(Train.head())
# Out:
#    Unnamed: 0  is_fraud  merchant_Mean_Encoded  state_Mean_Encoded  \
# 0           0         0               0.014207            0.004923
# 1           1         0               0.010787            0.005073
# 2           2         0               0.002111            0.001984
# 3           3         0               0.003444            0.002722
# 4           4         0               0.003769            0.006769
#
#    last_Mean_Encoded  city_pop_Mean_Encoded  cc_num_Mean_Encoded  \
# 0           0.000000               0.000000             0.000000
# 1           0.002633               0.003289             0.000000
# 2           0.008763               0.000000             0.000000
# 3           0.006576               0.030426             0.030426
# 4           0.008709               0.000000             0.000000
#
#    category_Mean_Encoded  first_Mean_Encoded  zip_Mean_Encoded  \
# 0               0.014458            0.007261          0.000000
# ...

# %% [markdown]
# # Encoding of the Testing Dataset

# %%
import matplotlib.pyplot as plt

# Assuming train is your DataFrame and "is_fraud" is a column in it
y_test = test["is_fraud"]

# Calculate value counts
z = y_test.value_counts()

# Create a pie chart
fig, ax = plt.subplots()
ax.pie(z, labels=z.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'black'])

# Draw a circle to make it a donut chart
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig.gca().add_artist(centre_circle)

# Equal aspect ratio ensures that pie is drawn as a circle
ax.axis('equal')  
plt.tight_layout()

# Show the plot
plt.title('Fraudulent vs Non-Fraudulent Transactions\n')

plt.show()

# %%
mean_encoding_map = test.groupby("job")['is_fraud'].mean().to_dict()

test['Job_Type_Mean_Encoded'] = test['job'].map(mean_encoding_map)

# %%
mean_encoding_map = test.groupby("merchant")['is_fraud'].mean().to_dict()

test['merchant_Mean_Encoded'] = test['merchant'].map(mean_encoding_map)

# %%
mean_encoding_map = test.groupby("state")['is_fraud'].mean().to_dict()

test['state_Mean_Encoded'] = test['state'].map(mean_encoding_map)

# %%
mean_encoding_map = test.groupby("last")['is_fraud'].mean().to_dict()

test['last_Mean_Encoded'] = test['last'].map(mean_encoding_map)

# %%
mean_encoding_map = test.groupby("city_pop")['is_fraud'].mean().to_dict()

test['city_pop_Mean_Encoded'] = test['city_pop'].map(mean_encoding_map)

# %%
mean_encoding_map = test.groupby("cc_num")['is_fraud'].mean().to_dict()

test['cc_num_Mean_Encoded'] = test['cc_num'].map(mean_encoding_map)

# %%
mean_encoding_map = test.groupby("category")['is_fraud'].mean().to_dict()

test['category_Mean_Encoded'] = test['category'].map(mean_encoding_map)

# %%
mean_encoding_map = test.groupby("first")['is_fraud'].mean().to_dict()

test['first_Mean_Encoded'] = test['first'].map(mean_encoding_map)

# %%
mean_encoding_map = test.groupby("zip")['is_fraud'].mean().to_dict()

test['zip_Mean_Encoded'] = test['zip'].map(mean_encoding_map)

# %%
mean_encoding_map = test.groupby("lat")['is_fraud'].mean().to_dict()

test['lat_Mean_Encoded'] = test['lat'].map(mean_encoding_map)

# %%
mean_encoding_map = test.groupby("long")['is_fraud'].mean().to_dict()

test['long_Mean_Encoded'] = test['long'].map(mean_encoding_map)

# %%
mean_encoding_map = test.groupby("unix_time")['is_fraud'].mean().to_dict()

test['unix_time_Mean_Encoded'] = test['unix_time'].map(mean_encoding_map)

# %%
mean_encoding_map = test.groupby("merch_lat")['is_fraud'].mean().to_dict()

test['merch_lat_Mean_Encoded'] = test['merch_lat'].map(mean_encoding_map)

# %%
mean_encoding_map = test.groupby("merch_long")['is_fraud'].mean().to_dict()

test['merch_long_Mean_Encoded'] = test['merch_long'].map(mean_encoding_map)

# %%
test['city_Mean_Encoded'] = test['city'].map(mean_encoding_map)

# %%
# Label Encoding
label_encoder = LabelEncoder()
test['gender_encoded'] = label_encoder.fit_transform(test['gender'])

# %%
col = ["merch_long","merch_lat","gender","unix_time","long","city","gender_encoded","lat",'zip','cc_num',"category",'first',"trans_date_trans_time", "trans_num","dob", "street","job","last","state","merchant","amt","last","city_pop"]
Test = test.drop(columns=col)
Test.head()
# Out:
#    Unnamed: 0  is_fraud  merchant_Mean_Encoded  state_Mean_Encoded  \
# 0           0         0               0.004076            0.003429
# 1           1         0               0.001274            0.000000
# 2           2         0               0.001325            0.004872
# 3           3         0               0.004219            0.002928
# 4           4         0               0.002703            0.003101
#
#    last_Mean_Encoded  city_pop_Mean_Encoded  cc_num_Mean_Encoded  \
# 0            0.00000               0.000000             0.000000
# 1            0.00706               0.000000             0.000000
# 2            0.00000               0.000000             0.000000
# 3            0.00706               0.015083             0.015083
# 4            0.00000               0.000000             0.000000
#
#    category_Mean_Encoded  first_Mean_Encoded  zip_Mean_Encoded  \
# 0               0.001780            0.000000          0.000000
# ...

# %% [markdown]
# # Logistic Regression

# %%
y_train = Train["is_fraud"]
col = ["is_fraud","gender_encoded"]
X_train = Train.drop(columns=col)
y_test = Test["is_fraud"]
col = ["is_fraud","Job_Type_Mean_Encoded"]
X_test = Test.drop(columns=col)
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
print(model.score(X_test, y_test)*100,"%")
# Out:
# 99.61401355721146 %

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train, y_train)
print(classifier.score(X_test, y_test)*100,"%")
# Out:
# 100.0 %

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train)
print(classifier.score(X_test, y_test)*100,"%")
# Out:
# 100.0 %
